# %% [markdown]
# quien tiene o no parkinson. SUPPORT VERCOR MACHINE CLASSIFIER

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df= pd.read_csv('C:/Users/Usuario/Desktop/data/siddhardhan/files/Parkinsson disease.csv')
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# 1 parkison 0 healthy

# %%
#groupíng the data based on the target variable
df.groupby('status').mean()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19672\3321359702.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('status').mean()
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# ...

# %%
X= df.drop(columns=['status', 'name'], axis=1)
Y=df['status']
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
#puse stratify=Y que sidd no lo puso, me cambio el X_train = scaler.transform(X_train)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,  random_state=2 )
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 123      182.018       197.173        79.187         0.00842
# 160      114.238       124.393        77.022         0.00581
# 94       157.821       172.975        68.401         0.00358
# 57       117.274       129.916       110.402         0.00752
# 41       184.055       196.537       166.977         0.00258
# ..           ...           ...           ...             ...
# 43       241.404       248.834       232.483         0.00281
# 22       167.930       193.221        79.068         0.00442
# 72       120.080       139.710       111.208         0.00405
# 15       142.167       217.455        83.159         0.00369
# 168      197.569       217.627        90.794         0.00803
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 123           0.00005   0.00506   0.00449     0.01517       0.02503
# 160           0.00005   0.00299   0.00316     0.00896       0.04009
# ...

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[ 0.63239631, -0.02731081, -0.87985049, ..., -0.97586547,
#         -0.55160318,  0.07769494],
#        [-1.05512719, -0.83337041, -0.9284778 , ...,  0.3981808 ,
#         -0.61014073,  0.39291782],
#        [ 0.02996187, -0.29531068, -1.12211107, ..., -0.43937044,
#         -0.62849605, -0.50948408],
#        ...,
#        [-0.9096785 , -0.6637302 , -0.160638  , ...,  1.22001022,
#         -0.47404629, -0.2159482 ],
#        [-0.35977689,  0.19731822, -0.79063679, ..., -0.17896029,
#         -0.47272835,  0.28181221],
#        [ 1.01957066,  0.19922317, -0.61914972, ..., -0.716232  ,
#          1.23632066, -0.05829386]])

# %%
model = svm.SVC(kernel='linear')

# %%
#trining the svm 
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
#accuracy
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score (Y_train, X_train_prediction )
training_data_accuracy
# Out:
# 0.8846153846153846

# %%
#accuracy test
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score (Y_test, X_test_prediction )
test_data_accuracy
# Out:
# 0.8717948717948718

# %%
input_data =[119.992,157.302,74.997,0.00784,0.00007,0.0037,0.00554,0.01109,0.04374,0.426,0.02182,0.0313,0.02971,0.06545,0.02211,21.033,0.414783,0.815285,-4.813031,0.266482,2.301442,0.284654]
input_data = np.asarray(input_data )
input_data = input_data.reshape(1,-1)

# %%
std_data = scaler.transform(input_data)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict(std_data)
prediction
# Out:
# array([1], dtype=int64)

# %%
if prediction[0]==0:
    print('no parkinsos')
else:
    print('Positive parkinson')
# Out:
# Positive parkinson
